# %%
TASK 2 - DATA SCIENCE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_data = pd.read_csv(r'C:\Users\LENOVO\OneDrive\Documents\intern\prodigy intership\prodigy -task 2\gender_submission.csv')

# %%
titanic_data
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
print("Number of missing values in each column:")
print(titanic_data.isnull().sum())
# Out:
# Number of missing values in each column:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
titanic_data = titanic_data.dropna()

# %%
print("\nSurvival counts:")
print(titanic_data['Survived'].value_counts())
# Out:
# Survival counts:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Survived', data=titanic_data)
plt.title('Distribution of Survival')
plt.xlabel('Survival (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PassengerId', y='Survived', data=titanic_data)
plt.title('Relationship between Passenger ID and Survival')
plt.xlabel('Passenger ID')
plt.ylabel('Survival (0 = No, 1 = Yes)')
plt.show()
